# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM 

tokenizer = AutoTokenizer.from_pretrained(
  'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
  bos_token='[BOS]', eos_token='[EOS]', unk_token='[UNK]', pad_token='[PAD]', mask_token='[MASK]'
)
model = AutoModelForCausalLM.from_pretrained(
  'kakaobrain/kogpt', revision='KoGPT6B-ryan1.5b-float16',  # or float32 version: revision=KoGPT6B-ryan1.5b
  pad_token_id=tokenizer.eos_token_id,
  torch_dtype='auto', low_cpu_mem_usage=True
).to(device='cuda', non_blocking=True)
_ = model.eval()
# Out:
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.40M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/839 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/11.5G [00:00<?, ?B/s]
# 인간처럼 생각하고, 행동하는 '지능'을 통해 인류가 이제까지 풀지 못했던 인간의 한계를 극복할 수 있는 새로운 시대에 맞는 창조와 지혜의 힘을 키울 수 있을 것으로 기대하면서 이번 학술대회를 개최하게 되었습니다."라고

# %%
prompt = '옛날 어느 마을에 바보가 살고있었어요'
with torch.no_grad():
  tokens = tokenizer.encode(prompt, return_tensors='pt').to(device='cuda', non_blocking=True)
  gen_tokens = model.generate(tokens, do_sample=True, temperature=0.8, max_length=64)
  generated = tokenizer.batch_decode(gen_tokens)[0]
  
print(generated)
# Out:
# 옛날 어느 마을에 바보가 살고있었어요 바보에게는 1년동안 바보라는 별명이 붙어있었어요 그 바보가 어떤일이 있었는지 바보의 이야기를 들어보세요.... 바보가 살았어요 바보는 태어나서 바보라는 별명이 붙었고, 항상 행복했답니다.
